# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

df = pd.read_csv("/home/csl4/Downloads/ObesityDataSet_raw_and_data_sinthetic.csv")
print(df)
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
print(df.columns)
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=2111, step=1)

# %%
print(df.dtypes)
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
print(df.size)
print(df.shape)
# Out:
# 35887
# (2111, 17)

# %%
df.loc[2,'Weight']   #loc is label based   # loc[row,col]
# Out:
# 77.0

# %%
df.loc[4]
# Out:
# Gender                                             Male
# Age                                                22.0
# Height                                             1.78
# Weight                                             89.8
# family_history_with_overweight                       no
# FAVC                                                 no
# FCVC                                                2.0
# NCP                                                 1.0
# CAEC                                          Sometimes
# SMOKE                                                no
# CH2O                                                2.0
# SCC                                                  no
# FAF                                                 0.0
# TUE                                                 0.0
# CALC                                          Sometimes
# MTRANS                            Public_Transportation
# NObeyesdad                          Overweight_Level_II
# ...

# %%
print(df["Gender"].head())
# Out:
# 0    Female
# 1    Female
# 2      Male
# 3      Male
# 4      Male
# Name: Gender, dtype: object

# %%
df.loc[1:3]
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
#
#                   MTRANS          NObeyesdad
# 1  Public_Transportation       Normal_Weight
# 2  Public_Transportation       Normal_Weight
# 3                Walking  Overweight_Level_I

# %%
df.iloc[1:3]  #iloc is index based and last value is exlcusive   # loc is label based and last index is inclusive
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
#
#                   MTRANS     NObeyesdad
# 1  Public_Transportation  Normal_Weight
# 2  Public_Transportation  Normal_Weight

# %%
# Data filtering

# %%
print(df[df.Age == 32])
# Out:
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 149  Female  32.0    1.67    90.0                            yes  yes   3.0
# 229    Male  32.0    1.75   120.0                            yes   no   3.0
# 278  Female  32.0    1.57    57.0                            yes  yes   3.0
#
#      NCP       CAEC SMOKE  CH2O SCC  FAF  TUE       CALC      MTRANS  \
# 149  1.0  Sometimes    no   2.0  no  2.0  0.0  Sometimes  Automobile
# 229  3.0  Sometimes    no   3.0  no  0.0  2.0         no  Automobile
# 278  3.0  Sometimes    no   2.0  no  0.0  0.0  Sometimes  Automobile
#
#           NObeyesdad
# 149   Obesity_Type_I
# 229  Obesity_Type_II
# 278    Normal_Weight

# %%
print(df[(df.Age == 21) & (df.Gender == "Female")])
 # using & condition for filtering
# Out:
#      Gender   Age    Height     Weight family_history_with_overweight FAVC  \
# 0    Female  21.0  1.620000  64.000000                            yes   no
# 1    Female  21.0  1.520000  56.000000                            yes   no
# 11   Female  21.0  1.720000  80.000000                            yes  yes
# 35   Female  21.0  1.500000  65.000000                            yes   no
# 37   Female  21.0  1.600000  48.000000                             no  yes
# 39   Female  21.0  1.750000  88.000000                            yes  yes
# 40   Female  21.0  1.670000  75.000000                            yes  yes
# 42   Female  21.0  1.660000  64.000000                            yes  yes
# 45   Female  21.0  1.530000  65.000000                            yes   no
# 49   Female  21.0  1.550000  50.000000                             no  yes
# 50   Female  21.0  1.610000  54.500000                            yes  yes
# ...

# %%
print(df.describe())   # describe the data with count,mean,std,etc.
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
df.isnull()
# Out:
#       Gender    Age  Height  Weight  family_history_with_overweight   FAVC  \
# 0      False  False   False   False                           False  False
# 1      False  False   False   False                           False  False
# 2      False  False   False   False                           False  False
# 3      False  False   False   False                           False  False
# 4      False  False   False   False                           False  False
# ...      ...    ...     ...     ...                             ...    ...
# 2106   False  False   False   False                           False  False
# 2107   False  False   False   False                           False  False
# 2108   False  False   False   False                           False  False
# 2109   False  False   False   False                           False  False
# 2110   False  False   False   False                           False  False
#
# ...

# %%
print(df.isnull().values.any())   # any NaN value is present or not ?
# Out:
# False

# %%
# Data Transformation

# %%
categorical_cols = df.select_dtypes(include="object").columns
numerical_cols = df.select_dtypes(include=["int64", "float64"]).columns

# %%
le = LabelEncoder()

for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

print(df)
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          0  21.000000  1.620000   64.000000                               1
# 1          0  21.000000  1.520000   56.000000                               1
# 2          1  23.000000  1.800000   77.000000                               1
# 3          1  27.000000  1.800000   87.000000                               0
# 4          1  22.000000  1.780000   89.800000                               0
# ...      ...        ...       ...         ...                             ...
# 2106       0  20.976842  1.710730  131.408528                               1
# 2107       0  21.982942  1.748584  133.742943                               1
# 2108       0  22.524036  1.752206  133.689352                               1
# 2109       0  24.361936  1.739450  133.346641                               1
# 2110       0  23.664709  1.738836  133.472641                               1
#
# ...

# %%
X = df.drop("NObeyesdad", axis=1)
y = df["NObeyesdad"]

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# %%
X_scaled.head()
# Out:
#      Gender       Age    Height    Weight  family_history_with_overweight  \
# 0 -1.011914 -0.522124 -0.875589 -0.862558                        0.472291
# 1 -1.011914 -0.522124 -1.947599 -1.168077                        0.472291
# 2  0.988227 -0.206889  1.054029 -0.366090                        0.472291
# 3  0.988227  0.423582  1.054029  0.015808                       -2.117337
# 4  0.988227 -0.364507  0.839627  0.122740                       -2.117337
#
#        FAVC      FCVC       NCP      CAEC     SMOKE      CH2O       SCC  \
# 0 -2.759769 -0.785019  0.404153  0.300346 -0.145900 -0.013073 -0.218272
# 1 -2.759769  1.088342  0.404153  0.300346  6.853997  1.618759  4.581439
# 2 -2.759769 -0.785019  0.404153  0.300346 -0.145900 -0.013073 -0.218272
# 3 -2.759769  1.088342  0.404153  0.300346 -0.145900 -0.013073 -0.218272
# 4 -2.759769 -0.785019 -2.167023  0.300346 -0.145900 -0.013073 -0.218272
#
#         FAF       TUE      CALC    MTRANS
# 0 -1.188039  0.561997  1.419172  0.503337
# ...
